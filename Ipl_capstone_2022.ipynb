# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramandeep-Singh17/Complete_data_visualization./blob/main/Ipl_capstone_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# These are some of the important columns that we'll focus on for meaningful insights in this project.
#
# column names: Variable Type
#
# date : string
#
# venue : string
#
# stage : string
#
# team1 : string
#
# team2 : string
#
# toss_winner : string
#
# toss_decision : string
#
# first_ings_score : integer
#
# second_ings_score : integer
#
# match_winner : string
#
# won_by : string
#
# margin : integer
#
# player_of_the_match : string
#
# top_scorer : string
#
# highscore : integer
#
# best_bowling : string
#
# best_bowling_fgure : string
#
# gure : string

# %%
#Loading the Libraries and Dataset
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
df = pd.read_csv( 'IPL.csv')

df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
#Check the size of rows and columns of the dataset

print(f"your rows are {df.shape[0]} and your columns are {df.shape[1]}")
# Out:
# your rows are 74 and your columns are 20

# %% [markdown]
# Now let's see how many columns have null values in total.

# %%
df.isnull().sum()#sum me true 1 hoga and false yu sero hi rahega
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
# Which team won the most matches?

# %%
match_wins = df['match_winner'].value_counts()
sns.barplot(x = match_wins.index,y = match_wins.values)
#yaha overlapp kar rha hai isliye x ko y and y ko x
# Out:
# <Axes: xlabel='match_winner'>

# %%
match_wins
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Punjab        7
# Delhi         7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
match_wins = df['match_winner'].value_counts()
sns.barplot(y = match_wins.index,x = match_wins.values,palette='viridis')
plt.title("Most match win by team ")# title ke liye
# Out:
# /tmp/ipython-input-15-970244019.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = match_wins.index,x = match_wins.values,palette='viridis')
# Text(0.5, 1.0, 'Most match win by team ')

# %% [markdown]
# 2.
# Toss Decision Trends

# %%
sns.countplot(x = df['toss_decision'],palette='rainbow')
plt.title("Toss Decision Trends ")
# Out:
# /tmp/ipython-input-16-3419294191.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['toss_decision'],palette='rainbow')
# Text(0.5, 1.0, 'Toss Decision Trends ')

# %% [markdown]
# 3.Toss Winner vs Match Winner

# %%
count = df[df['toss_winner'] == df['match_winner']]
count
# sare mil gaye jo match bhi jeeta and toss bhi
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 5          6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6          7  March 31,2022                     Brabourne Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 12        13   April 5,2022                      Wankhede Stadium, Mumbai
# 13        14   April 6,2022  Maharashtra Cricket Association Stadium,Pune
# 14        15   April 7,2022            Dr DY Patil Sports Academy, Mumbai
# 15        16   April 8,2022                     Brabourne Stadium, Mumbai
# 16        17   April 9,2022            Dr DY Patil Sports Academy, Mumbai
# ...

# %%
count = df[df['toss_winner'] == df['match_winner']]['match_id'].count()
count
# Out:
# np.int64(36)

# %%
count = df[df['toss_winner'] == df['match_winner']]['match_id'].count()
percentage = (count *100)/df.shape[0]
percentage.round(2)
#in percentage
# Out:
# np.float64(48.65)

# %% [markdown]
# 4.How do teams win? (Runs vs Wickets)

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
sns.countplot(x = df['won_by'])
plt.title("Won by")
# so 37 won by wickets and 37 won by runs
# Out:
# Text(0.5, 1.0, 'Won by')

# %% [markdown]
# Key Player Performances
#
# 1 Most "Player of the Match" Awards

# %%
count = df['player_of_the_match'].value_counts()
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# K L Rahul            2
# Yuzvendra Chahal     2
# David Miller         2
# Jasprit Bumrah       2
# Umran Malik          2
# Evin Lewis           1
# Abhishek Sharma      1
# Pat Cummins          1
# Liam Livingstone     1
# Lockie Ferguson      1
# Shivam Dube          1
# Sanju Samson         1
# Odean Smith          1
# Mohammed Shami       1
# Mayank Agarwal       1
# Anuj Rawat           1
# Kane Williamson      1
# Faf du Plessis       1
# Rashid Khan          1
# Marco Jansen         1
# Shikhar Dhawan       1
# Mukesh Choudhary     1
# Krunal Pandya        1
# Rahul Tewatia        1
# Suruakumar Yadav     1
# Mohsin Khan          1
# Ruturaj Gaikwad      1
# Rinku Singh          1
# Kagiso Rabada        1
# ...

# %%
count = df['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(x = count.values,y = count.index,palette='mako')
plt.title("Most Player of the Match Awards")
# Out:
# Text(0.5, 1.0, 'Most Player of the Match Awards')

# %% [markdown]
# 2 Top scorrers

# %%
df.head()# top scorrers column hai wo check karne ke liye
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
high=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(10)
high
# Out:
# top_scorer
# Jos Buttler         651
# Quinton de Kock     377
# KL Rahul            351
# Shubman Gill        288
# Faf du Plessis      257
# Liam Livingstone    239
# David Warner        213
# W. Saha             190
# Ishan Kishan        180
# Shikhar Dhawan      158
# Name: highscore, dtype: int64

# %%
high.plot(kind='bar',color='red')
plt.title("Top Scorers")
# Out:
# Text(0.5, 1.0, 'Top Scorers')

# %% [markdown]
# 10 Best bowling figures

# %%
df["highest_wicket"]= df['best_bowling_figure'].apply(lambda x: x.split('--')[0])
df["highest_wicket"]
# Out:
# 0     3
# 1     3
# 2     2
# 3     3
# 4     3
#      ..
# 69    3
# 70    1
# 71    3
# 72    3
# 73    3
# Name: highest_wicket, Length: 74, dtype: object

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x :x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# Most Matches Played by Venue

# %%
venue_count = df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y = venue_count.index,x = venue_count.values,palette='rainbow')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# Custom Questions & Insights
#
# Q1: Who won the highest margin by runs?

# %%
df[df['won_by'] == 'Runs']#pahle hm nikale hai ki kaunkaun run se jita hai
# Out:
#     match_id           date                                         venue  \
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 8          9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9         10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
# 10        11   April 3,2022                     Brabourne Stadium, Mumbai
# 11        12   April 4,2022            Dr DY Patil Sports Academy, Mumbai
# 18        19  April 10,2022                     Brabourne Stadium, Mumbai
# 19        20  April 10,2022                      Wankhede Stadium, Mumbai
# 21        22  April 12,2022            Dr DY Patil Sports Academy, Mumbai
# 22        23  April 13,2022  Maharashtra Cricket Association Stadium,Pune
# 23        24  April 14,2022            Dr DY Patil Sports Academy, Mumbai
# 25        26  April 16,2022                     Brabourne Stadium, Mumbai
# 26        27  April 16,2022                      Wankhede Stadium, Mumbai
# ...

# %%
df[df['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False)
#ab hme 1st wala chahiye
# Out:
#     match_id           date                                         venue  \
# 54        55     May 8,2022            Dr DY Patil Sports Academy, Mumbai
# 52        53     May 7,2022  Maharashtra Cricket Association Stadium,Pune
# 53        54     May 8,2022                      Wankhede Stadium, Mumbai
# 56        57    May 10,2022  Maharashtra Cricket Association Stadium,Pune
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 60        61    May 14,2022  Maharashtra Cricket Association Stadium,Pune
# 59        60    May 13,2022                     Brabourne Stadium, Mumbai
# 10        11   April 3,2022                     Brabourne Stadium, Mumbai
# 55        56     May 9,2022            Dr DY Patil Sports Academy, Mumbai
# 18        19  April 10,2022                     Brabourne Stadium, Mumbai
# 23        24  April 14,2022            Dr DY Patil Sports Academy, Mumbai
# 36        37  April 24,2022                      Wankhede Stadium, Mumbai
# ...

# %%
df[df['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# Q2: Which player had the highest individual score?

# %%
df[df['highscore'] == df['highscore'].max()]
# Out:
#     match_id         date                               venue    team1  \
# 65        66  May 18,2022  Dr DY Patil Sports Academy, Mumbai  Kolkata
#
#       team2  stage toss_winner toss_decision  first_ings_score  \
# 65  Lucknow  Group     Lucknow           Bat               210
#
#     first_ings_wkts  ...  match_winner  won_by margin player_of_the_match  \
# 65                0  ...       Lucknow    Runs      2     Quinton de Kock
#
#          top_scorer highscore best_bowling  best_bowling_figure  \
# 65  Quinton de Kock       140  Mohsin Khan                3--20
#
#    highest_wicket highest_wickets
# 65              3               3
#
# [1 rows x 22 columns]

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]# jo hme nikalna hai use bahar kar diye
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# Q3: Which bowler had the best bowling figures?

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
