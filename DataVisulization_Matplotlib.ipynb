# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramandeep-Singh17/Complete_data_visualization./blob/main/DataVisulization_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Matplotlib Basics

# %%
x = np.linspace(0,5,11)#linear space from 0 to 5
x
y = x **3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("bhaiya")# bas ye dikhane ke liye ki hm xy axis pe kuch bhi likh sakte hai
plt.ylabel("Bhabhi")
# Out:
# Text(0, 0.5, 'Bhabhi')

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,4)
plt.subplot(2,2,3)
plt.subplot(2,2,2)
# plt.subplot(2,2,4) hm 2,2,5 likhenge tu error aayeha kyuki 4 hi part me devide kiye hai
# Out:
# <Axes: >

# %% [markdown]
#  **Subplots in Matplotlib**

# %%
plt.subplot(2,2,1)# we prodvide rows and columns
# ye subplot btata hai ki maanlo ek canvas hai and use hm 2x2 ke rows and column me baat diye upper dikhaya hai
# and tab hm jo 1 likhe hai uska mtlb hua ki jo 4 bna hai usme se 1st wale ko select karenge.
#hme subplot me 3  pass karna hi hoga kyuki 2x2 bna denge but ek tu select karenge hi na.
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)#bas x aisx pe y hai dont confuse mat hona.
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %%
plt.subplot(6,6,1)
#  hm usi canvas 6x6 ke 36 me change kar diye hai
# Out:
# <Axes: >

# %% [markdown]
# # Object Oriented way
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(20,8),dpi = 120)#dpi high quality karta hai
axis1=fig.add_axes([0.1,0.1,.4,.8])#left bottom  width height sab me yhi rahgea
axis1.plot(x,y)
# agae do denge tab overlap hone lagega.
axis2 = fig.add_axes([0.3,0.4,.3,.3])
axis2.plot(x,y)

# %% [markdown]
# **Types of Plots**

# %%
#1scatterplot
plt.scatter(x,y)

# %%
#2 histogram
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([11.,  8.,  8., 10., 12.,  8.,  8., 11., 12., 12.]),
#  array([ 18., 116., 214., 312., 410., 508., 606., 704., 802., 900., 998.]),
#  <BarContainer object of 10 artists>)

# %%
#3 boxplot
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b5d51bdda90>,
#   <matplotlib.lines.Line2D at 0x7b5d51bde650>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b5d51bdefd0>,
#   <matplotlib.lines.Line2D at 0x7b5d51bdfbd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b5d51d45090>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b5d51bec8d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b5d51bed450>],
#  'means': []}

# %% [markdown]
# # Saving Plots

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")# ab ye figure mere file me hai
# ye hme wahi milega jha hm csv data upload karte hai.

# %% [markdown]
# **Working with Images**

# %%
import matplotlib.image as mpimg
#matplotlib images pe kaam karsakta hai jo seaborn nhi kar sakta
#matplotlib numpy per kaam karta hai isliye

# %%
img = mpimg.imread('images.jpeg')
img
plt.imshow(img)
# plt.axis('off')

# %%
img = mpimg.imread('images.jpeg')
img
plt.imshow(img)
#axis hatane ke liye
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(451.5), np.float64(677.5), np.float64(-0.5))

# %%
cropped_img = img[50:200, 100:300]  # crop: rows 50-200, cols 100-300
plt.imshow(cropped_img)
plt.axis('off')
#image numpy array ke form me tuta hai and use dekhne ke liye ye karna padega
# iska use mainly deeplearning me hai
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %% [markdown]
# **OPTIONAL DESIGNING**

# %%
plt.plot(x,y,color = "pink")

# %%
xaxis = np.linspace(0,5,11)
# ye sare tarike hai jisse line ko dikha sakte ho

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8,
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
